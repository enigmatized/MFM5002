# %% [markdown]
# This felt like a tricky problem, even though it really wasn't.
#
# Some aspect I had trouble with:
#
# 1. $ (X,Y) $ is chosen $uniformly$. I didn't get this at first, but by the definition of a uniform distribution over a region of area $A$ has a constant PDF of $\frac{1}{A}$ everywhere inside the region and $0$ outside...... So we are working with probability in that line. I am wondering how might this be used in real life?
#
#
# 2. Obviously our area of $Disk$ is $9\pi$. So our pdf is something life
#
#
# $
# f_{X,Y}(x,y)
# \;=\;
# \begin{cases}
# \displaystyle \frac{1}{\pi \cdot 3^2} \;=\;\frac{1}{9\pi},
# & \text{if } (x-1)^2 + (y+2)^2 \;\le\; 9, \\
# 0, & \text{otherwise}.
# \end{cases}
# $
#
# ##### Note
#
# $
# f_{X,Y}(x,y) \;=\;
# \begin{cases}
# \displaystyle
# \frac{1}{9\pi},
# & (x,y)\in D, \\
# 0, & \text{otherwise}.
# \end{cases}
# $
#
#
# This ensures that the total probability over the entire disk is $1$.

# %% [markdown]
# $
# \textbf{Given:} \quad D \;=\; \{(x,y)\;:\;(x-1)^2 + (y+2)^2 \;\le\; 9\}.
# $
# This is a disk of radius $3$ centered at $(1, -2)$. A point $(X,Y)$ is chosen uniformly from $D$.
#
# $
# \textbf{(a) Find the conditional PDF } f_{Y\mid X}(y\mid x).
# $
#
# I would say the hardest part about this, and what I would say I got wrong the first time attempting this was the bounds.
#
# I just treated this like a double intergral, and thought I could integrate (-2,4) for x.
#
# That is not the right way to approach this problem.

# %% [markdown]
# $\textbf{Part 2: Deriving the interval for }y\text{ given }x\text{.}$
#
# $(x-1)^2 + (y+2)^2 \;\le\; 9 $ is all $(x,y)$ inside the circle of radius $3$ centered at $(1,-2)$.
#
# - For a $x$, I can solve for the possible $y$-values as follows:
#   $
#   (y+2)^2 \;\le\; 9 \;-\; (x-1)^2.
#   $
# - Then taking square roots:
#   $
#   y + 2 \;\le\; \sqrt{\,9 - (x-1)^2\,}
#   \quad\text{and}\quad
#   y + 2 \;\ge\; -\,\sqrt{\,9 - (x-1)^2\,}.
#   $
#
# - Thus $ -\,\sqrt{\,9 - (x-1)^2\,} \;\le\; y + 2 \;\le\; \sqrt{\,9 - (x-1)^2\,}. $
#
# - $
#   -\,2 \;-\; \sqrt{\,9 - (x-1)^2\,}
#   \;\le\;
#   y   \;\le\;   -\,2 \;+\; \sqrt{\,9 - (x-1)^2\,}. $
#
# - So the lower bound for $y$ is
#   $
#   -2 - \sqrt{\,9 - (x-1)^2\,},
#   $
#   and the upper bound for $y$ is
#   $
#   -2 + \sqrt{\,9 - (x-1)^2\,}.
#   $
# - Geometrically, this is exactly the vertical “slice” of the circle for the chosen $x$.
#
# Finally, the length of this interval is:
# $
# \Bigl[-2 + \sqrt{\,9 - (x-1)^2\,}\Bigr]
# \;-\;
# \Bigl[-2 - \sqrt{\,9 - (x-1)^2\,}\Bigr]
# \;=\;
# 2\,\sqrt{\,9 - (x-1)^2\,}.
# $
# That expression arises just by subtracting the lower bound from the upper bound.
#
# $
# \text{Hence for a given }x,\; y \text{ must lie between } -2 \pm \sqrt{\,9 - (x-1)^2\,},
# $
#
# $
# \text{ and the length of that }y\text{-interval is } 2\sqrt{\,9-(x-1)^2\,}.
# $

# %% [markdown]
# For x in $(-2, 4)$ then the associated $y$ -values lie between:
# $ y \;\in\; \Bigl[-2 - \sqrt{\,9 - (x-1)^2\,}, \; -2 + \sqrt{\,9 - (x-1)^2\,}\Bigr].$

# %% [markdown]
# So then our marginal PDF of $X$ is
# $
# f_{X}(x)
# \;=\;
# \int_{y=-2-\sqrt{9-(x-1)^2}}^{\,-2+\sqrt{9-(x-1)^2}}
# f_{X,Y}(x,y)\,dy
# \;=\;
# \int_{-2-\sqrt{9-(x-1)^2}}^{-2+\sqrt{9-(x-1)^2}}
# \frac{1}{9\pi}\;dy
# \;=\;
# \frac{1}{9\pi}\,\cdot \;2\,\sqrt{\,9 - (x-1)^2\,}.
# $
#
# Therefore, the conditional PDF of $Y$ given $X=x$ is
# $
# f_{Y\mid X}(y\mid x)
# \;=\;
# \frac{f_{X,Y}(x,y)}{f_X(x)}
# \;=\;
# \frac{\frac{1}{9\pi}}
# {\frac{1}{9\pi}\,\cdot 2\,\sqrt{\,9 - (x-1)^2\,}}
# \;=\;
# \frac{1}{\,2\,\sqrt{\,9 - (x-1)^2\,}\,},
# $
# valid for
# $
# -2 - \sqrt{\,9 - (x-1)^2\,} \;\le\; y \;\le\; -2 + \sqrt{\,9 - (x-1)^2\,}.
# $

# %% [markdown]
# ### $\textbf{(b) Compute } P\bigl(Y>0 \mid X=2\bigr).$
#
# First, determine the interval of possible $y$-values when $x=2$.
#
#
# We plug $x=2$ into the circle equation:
# $
# (2 - 1)^2 \;+\; (y+2)^2 \;\le\; 9
# \quad\Longrightarrow\quad
# 1 \;+\; (y+2)^2 \;\le\; 9
# \quad\Longrightarrow\quad
# (y+2)^2 \;\le\; 8
# \quad\Longrightarrow\quad
# -\,\sqrt{8} \;\le\; y+2 \;\le\; +\,\sqrt{8}.
# $

# %% [markdown]
# So,
# $
# y \;\in\; \Bigl[-2 - \sqrt{8},\, -2 + \sqrt{8}\Bigr].
# $
# Note that $\sqrt{8} = 2\sqrt{2}$.  Therefore the interval is
# $
# y \;\in\; \bigl[-2 - 2\sqrt{2},\,-2 + 2\sqrt{2}\bigr].
# $
# We want $P\bigl(Y>0 \mid X=2\bigr)$.  Given $X=2$, $Y$ is uniform on that interval.  The total length of that interval is
# $
# \bigl[-2 + 2\sqrt{2}\bigr] \;-\;\bigl[-2 - 2\sqrt{2}\bigr]
# \;=\;
# 4\,\sqrt{2}.
# $

# %% [markdown]
# To find $P(Y>0)$, I have to look at how much of that interval is above 0.
#
# - The lower bound of the portion above 0 is $0$.
# - The upper bound is $-2 + 2\sqrt{2}$.
#
#
#
# Then the length of the interval above $0$ is
# $
# \bigl(-2 + 2\sqrt{2}\bigr) \;-\; 0
# \;=\;
# -2 + 2\sqrt{2}.
# $
#
# So,
# $
# P\bigl(Y>0 \mid X=2\bigr)
# \;=\;
# \frac{\text{(length above }0)}{\text{(total length)}}
# \;=\;
# \frac{-2 + 2\sqrt{2}}{4\sqrt{2}}
# \;=\;
# \frac{2(\sqrt{2}-1)}{4\sqrt{2}}
# \;=\;
# \frac{\sqrt{2}-1}{2\sqrt{2}}
# \;=\;
# \frac{2-\sqrt{2}}{4}.
# $

# %% [markdown]
# \begin{aligned}
# P\bigl(Y>0 \mid X=2\bigr)
# =
# \frac{\sqrt{2}-1}{2\sqrt{2}}
# =
# \frac{2-\sqrt{2}}{4}.
# \end{aligned}
