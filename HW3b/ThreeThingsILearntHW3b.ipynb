# %% [markdown]
# Three things I learned.
#
# These usually take me a long time—several hours.
# Time-wise, that's not a problem because I often find these more fruitful than the actual homework. That is not saying the homeworks, are not fruitful, its just I get so much out of trying to explain my ideas in english and explore sticking points.
# I think the purpose of these, or the way they were designed, was to explore things I can teach, that I have learnt.
# But I really like exploring the things I do really know, then exploring that "unknowing", and see why.
# Then explain why, and what was the sticking point.
#
# I tried this, but I don’t have the time to do the job to a level I’d feel is sufficient or something I’d be proud of.
# So is life sometimes.
#
# Three things I learned:
#
#     1. I want to go over variance and covariance proofs.
#     2. I want to review the Jacobian (which we use for transformations, also known as convolutions).
#     3. Addition and summation of multiple random variables.
#     4. I want to go over the total law of expectation and get a better understanding of the total law of variance.

# %% [markdown]
# # 1. Simple var(x + y) to covariance derivation
# I am aware of this, but I am not able to clearly teach it.
# I want the ability to clearly derive and articulate where the covariance falls from.
# This is a bit of stream of conciouness.
#
#
#
# So we have
# $var(x) = E[x^2] -E[x]^2$
#
# Now we want to add two variables.
# Thus we have.
# $var(x + y)$
#
# Using the definiton of var
# $var(x + y) = E[(x+y)^2] -E[x + y]^2$
#
# Now using properties of expectation and factoring the squared terms:
#
# $var(x + y) = E[x^2 +2xy + y^2] -E[x + y]^2$
#
# $var(x + y) = E[x^2 +2xy + y^2] - (E[x + y])^2$
#
# $var(x + y) = E[x^2 +2xy + y^2] - (E[x] + E[y])^2$
#
# $var(x + y) = E[x^2 +2xy + y^2] - (\mu_x^2 + 2\mu_x\mu_y + \mu_x^2)$
#
# $var(x + y) = E[x^2] + E[2xy] + E[y^2] - (\mu_x^2 + 2\mu_x\mu_y + \mu_x^2)$
#
# oh this is nice
#
# $var(x + y) = (E[x^2] - \mu_x^2) + (E[y^2] - \mu_x^2) + (E[2xy] - 2\mu_x\mu_y)$
#
# Using definition of var
#
# $var(x + y) = var(x)+ var(y)  + (E[2xy] - 2\mu_x\mu_y)$
#
# $var(x + y) = var(x)+ var(y)  + (2E[xy] - 2\mu_x\mu_y)$
#
# $var(x + y) = var(x)+ var(y)  + 2(E[xy] - \mu_x\mu_y)$
#
# Not defintion of covariance $Cov(x, y) = E[xy] - E[x]E[y]$
#
# Thus we have
#
# $var(x + y) = var(x)+ var(y)  + 2Cov(x, y)$
#
#
#
# That feels good.
#
# Not this can easily be generalized to
# $var(x+y+z+d)....$ if they are independet.

# %% [markdown]
# # Next I should review conditional expectation
#
# So I know $E(x) =  \sum x P(x)$
#
# We also know
#
# $P(a | b) = \frac{a \cap b}{ b}$
#
# So what does that mean for
#
# $$E(x | c) $$
#
# First, what are we saying here?
# It represents the average (or expected) value of X when we know that C has occurred.
#
# Let's stop for a second and think what is going on.
#
# We want to find the average value given $C$ has happened.
#
# So since $P(C)$ is a probability, or probability space, we are scaling it to this area.
# So in some respects, this will enlarge are $p(x \cap c)$ (given that the events are not disjoint).
#
# So going back to the expectation.
#
#
#
#
# What if we took the definiton above and combined them?
#
#
# $E(x | c)=  E\frac{x \cap c}{ c} $
#
# Well that is the wrong thing to do.
#
# Because that is mixing set theory with random variables.
#
# $E(X \mid C) = \sum_{x} x \, P(X = x \mid C) = \sum_{x} x \, \frac{P(\{X = x\} \cap C)}{P(C)}$

# %% [markdown]
# There is a reason to stop and think here.
#
# Expectation feels like a very strange.
# Every event is weighted with a value.
# Your event x really weight really effects the expecation.
#
#
# I think this line of thought is helping me see transformation.
#
#
# For example this of a dice(die?), that is an increasing number.
#
# Now, for questions sake,
# say you are in an interview and you are asked,
# given either a 5 or 6 was rolled, what has a higher expection, if a 5 or 6 is rolled.
#
#
# This isn't a trick question, it is just a question of whether you actually know you definition.
#
#
# The chance of either a 5 or 6 has been rolled is the same.
# But the x_i of 6 make the expecation larger even the probabilites are the same.
#
# I am going on this tangent because it is intresting here there is an extra weight-ing on event six.
#
# I might be bringing too much value to this, but what if we had a six sided die, but no number, just colors.
#
# They all have the same weighting.
#
# So that is a different problem.
#
# Where your variance is zero.
#
# You mean is 1.
#
# ...
#
# This leads me to think of transformations.
#
# That the transformation, just "scales" or puts different weighting on our x values.
#
#
# So there is a x value. We should just call it an event.
# And in the event we can place different weights to it.
# If we keep the same distrobution, but change the weights.
#
# say a discrete uniform.
# We multiple it by 2.
#
# We know mathmatically the expcation is 2x.
# That really isn't much of a transformation.
#
# But what if we square our events?
#
# Say again uniform.
#
# Maybe discrete, so is easier to visualize.
#
# $x = {1,2,3}$
# $E[x] = 1$
#
# $x^2 = {1,4,9}$
# $E[x] = 4 +\frac{1}{3}$
#
# So this is more of an intresting transformation.
#
# The weights are now non-linear increasing.
#
# Our mean size changing.
#
# What are we doing, expoentntial our weight, as I am calling them.
#
# Which is a set, and applying the $f(x) = x^2$
#
#
# So I am trying to see a connection with the jacobian.
#
#
# Say we have $x^2$ and we transform it to $x$
#
# Would that be saying that taking the derivitive of $x^2$ is $2x$
#
# Okay, but I am missing something.
#
# The transformation to make  $x^2$ is  $^0.5$
#
# So say the jocbian is 2.
#
# h(x) * jacobian * derivative of our new function equals... that is just the inverse....
#
#
# ===========================
#
# ### that was a dead end.
#
#
#
# Awww okay.
#
# I think the reason I am struggling with this, and I think I starting to have a break through is that, there is some hazy/vagueness/lack of understanding going on.
#
# Apart of it has to do with just my single variable transformations.
#
# So here is a funny question.
#
# If I have a f(x) of some probabiility distrbotuon.
#
# Say make it g(f(x))
#
# How does this distrboution change?
#
# Well first I have to ask, what is f(x)?
#
#
# It is easy to get caught up in notation.
#
# So let's go back to probaility basics.
#
# Say event is assigned a weight.
# That is the definiton of our random variable.
#
# so f(x)
#
# now we assign probabilities in such a way that all x for f(x) has an assocaited probability.
#
# So we almost have multiple transformations to begin with.
#
# We have an event.
# We have a number prescribed to it.
# We have a probability prescribed to that.
#
#
# So if transform our number generator, our random varibale, our probability prescription does not change, because those are paried, but our weighting does change.
#
# I believe that is all we are dealing with, when it comes to a single transform.
#
# Now going to the double variable case.
#
# Why do we add the jacobian? (Note that the derivative )
#
# so $h(x,y)$
#
# $f(x, y)$
#
#
# Which is $f(x,y) =$
#
# So say we have a random variable.
# X and random Varible Y
#
# Now we combine them.
#
# X+Y
#
# say of different probability distrobution.
#
# dice.
# normal random variable of mu =2 and sd = 4
#
# Dice are really good example of X + X = Y
#
#
# Say now we do Y^2
#
# So (say our dice is 3 sided)
#
#
#
#
#
# P(x)P(y)

# %% [markdown]
# Oh the issue I was having was the fact, of the
#
# $\frac{d}{dy} g^{-1}(y) \, dy$
#
# In the below.
#
# $ \int_{y_{\min}}^{y_{\max}} f_X(g^{-1}(y)) \cdot \frac{d}{dy} g^{-1}(y) \, dy$
#
#
# I actually think this is a weakness in my understanding of calculus notation.
# I really need to spend time on that.
#
# But I think I was getting confused
#
#
# $ f_x(x) = \int_{y_{\min}}^{y_{\max}} f_X(g^{-1}(y)) \cdot \frac{d}{dy} g^{-1}(y) \, dy$
#
# Because I thought
#
# $f_X(g^{-1}(y))$ should integrate to 1 if integrating from the bounds of x min and x max.
#
# The part I was over looking as the dx aspect of that.
# I overlooking that part when doing my integrals, I just write dx or sometimes forget to write it entirely, but it is accounting for the stretching factor.
#
#
# So when we do the transform, and we want the probability, we are substituing dy for dx in a sense.
#
# Meaning, say we have,
#
# $\int_{y_{\min}}^{y_{\max}} f_X(g^{-1}(y)) \cdot \frac{d}{dy} g^{-1}(y) \, dy$
#
#
# If we subsitutde $x$ then we need to subsitute $\frac{d}{dy} g^{-1}(y) = dx$
#
#
#
#
#
# Now switching to Jacobian, this makes total dense.
#
# as the pdf of $x$ and $y$ on $\int f_{x,y} (x,y) dx dy$ so the determinent of the Jocobian, make entire sense.
#
# It is just the dx.
#
# Now explaining the determinent, why that is the stretching factor/area is something I should spend the next write up.

# %% [markdown]
# I think the next thing I should cover is vector of random varibales, matrix of random variebles.
# I think that will help me cover the jacobian.
# This is forcing me to review some linear algebra.

# %%
import scipy.linalg as la
import numpy as np

A = np.array([[1, 2], [3, 4]])

la.det(A)
# Out:
# np.float64(-2.0)
