# %% [markdown]
# #### P5 A
#
#
# So we know
# - A is invertible
# - A and B are similiar
#
#
# We know that means
#
#
# $B = P^{-1}AP$
#
#
# For $B$ to be invertible We need $B B^{-1} = B^{-1}B = I$
#
# If $B^{-1} = (P^{-1}AP) ^{-1} = P^{-1} A^{-1} P$
#
#
#
#
# Let's multiply  $P^{-1}AP$ by $ P^{-1} A^{-1} P$
#
# $ (P^{-1}AP)(P^{-1} A^{-1} P)$
#
# $ (P^{-1}AA^{-1} P)$
#
# $ (P^{-1} P)$
#
# $ I$
#
# This implies $B$ is invertible (we should check the other side, but that is trivial.)
#
#
# We also know that since $B$ is invertible.
#
# $B^{-1} = (P^{-1}AP) ^{-1} = P^{-1} A^{-1} P$
#
# Thus, $A^{-1}$ is similiar to $B^{-1}$
#
#
#
#
# ### Key Properties of Similar Matrices:
# - They have the same eigenvalues.
# - They have the same determinant and trace.
# - They have the same characteristic polynomial.
# - Their rank and nullity are the same.

# %% [markdown]
# #### P5 B
#
# This does not seem that crazy.
#
# Here we go.
#
#
# So if $B = (P^{-1}AP)$
#
# Then let's multply by $(P^{-1}AP)$
#
# $B(P^{-1}AP) =  (P^{-1}AP)(P^{-1}AP)$
#
# $B^2 =  (P^{-1}A^2P)$
#
# Thus $A^2$ is similiar to $B^2$

# %% [markdown]
# #### P5 C
# $B = (P^{-1}AP)$
#
# and
# $C = (P^{-1}BP)$
#
# then
#
# $CP^{-1} = (P^{-1}BP)P^{-1}$
#
# $PCP^{-1} = PP^{-1}B$
#
# $PCP^{-1} = B$
#
#
# $PCP^{-1} = B = (P^{-1}AP)$
#
# $C = P^{-1}(P^{-1}AP)P$
#
#
#
# #### that is entirely correct because I used the same matrix P for both, which does not prove for all cases.
#
#
# #### P5 C
# $B = (P^{-1}AP)$
#
# and
# $C = (Q^{-1}BQ)$
#
# then
#
# $CQ^{-1} = (Q^{-1}BQ)Q^{-1}$
#
# $QCQ^{-1} = QQ^{-1}B$
#
# $QCQ^{-1} = B$
#
#
# $QCQ^{-1} = B = (P^{-1}AP)$
#
# $C = Q^{-1}(P^{-1}AP)Q$
#
# Thus

# %% [markdown]
# #### P5 D
#
# So if $A = P D P^{-1}$
#
# And
# $ B = Q^{-1} A Q = Q^{-1}P D P^{-1}Q $
#
#
# lets call
#
# $ Q^{-1}P  = R$
#
# Note $ Q^{-1}P P^{-1}Q  = I$
#
# So
#
# $B = R D R^{-1}  $

# %% [markdown]
# #### P5 E
#
# We could say as properties of Similar matrices, but that isn't showing anything.....
#
# If
# $B = (P^{-1}AP)$
#
# So what are we saying here
#
# $Ax = \lambda x$
#
# $BP^{-1} = P^{-1}APP^{-1}$
#
#
# $BP^{-1}x = P^{-1}Ax$
#
# $PBP^{-1}x = PP^{-1}Ax$
#
# $PB(P^{-1}x) = Ax$
#
# $PBP^{-1}x = \lambda x$
#
# $BP^{-1}x = P^{-1} \lambda x$
#
# $P^{-1}x = B^{-1}P^{-1} \lambda x$
#
#
# ## Okay the above is wrong
#
# $P^{-1}Ax = P^{-1}\lambda x = \lambda P^{-1} x $
#
# If $P^{-1} x $ then
# $P P^{-1} x = x $
#
# $ Ax = AP P^{-1} x = \lambda P P^{-1} x $
#
# So
#
# $ P^{-1}Ax = P^{-1}AP P^{-1} x  = B P^{-1} x  = P^{-1}A x  =P^{-1} \lambda x $

# %% [markdown]
# #### P5 F
#
# A is similiar B
#
# So $B = (P^{-1}AP)$
#
# Note $Tr(A)$ the sum of the diagonal elements of $A$.
#
# Well we know
# $Tr(B) = Tr((P^{-1}AP))$
#
#
# There is propety of
#
# $Tr(GH) = Tr(HG)$
#
# So I wonder if
#
# $Tr(B) = Tr((P^{-1}AP)) = Tr(A (PP^{-1})) =  Tr(A)$
