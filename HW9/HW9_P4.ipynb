# %% [markdown]
# Steps.
# 0. Make sure it applies to the matrix at hand... (symmetric, or noraml matrices)
# 1. Find Eigienvalues
# 2. Find eignevectors
# 3. Then simply sum the multitplied out the $\lambda_n$ by the corresponding $vector_n \times vector_n ^T$

# %% [markdown]
# $\textbf{Step 1.  Characteristic equation}$
#
#
# $
# \det(A-\lambda I)
# =(7-\lambda)(4-\lambda)-2\cdot2
# =\lambda^{2}-11\lambda+24=0.
# $
#
#
# $
# \Longrightarrow \lambda_{1}=8,\;\lambda_{2}=3.
# $
#
#
# $
# \textbf{Step 2.  Eigenspaces}
# $
#
#
#
# $
# \lambda_{1}=8:
# \;A-8I=\begin{pmatrix}-1&2\\2&-4\end{pmatrix}
# \to (-1)x+2y=0\Rightarrow x=2y.
# \text{Basis vector }v_{1}=(2,1)^{\top}.
# $
#
#
# $
# \lambda_{2}=3:
# \;A-3I=\begin{pmatrix}4&2\\2&1\end{pmatrix}
# \to 4x+2y=0\Rightarrow x=-\tfrac12 y.
# \text{Basis vector }v_{2}=(-1,2)^{\top}.
# $
#
#
# $
# \textbf{Step 3. Normalize and verify orthogonality}
# $
#
#
#
# $
# \|v_{1}\|=\sqrt{2^{2}+1^{2}}=\sqrt5,\;
# u_{1}=v_{1}/\!\sqrt5=\frac1{\sqrt5}(2,1)^{\top}.
# $
#
#
# $
# \|v_{2}\|=\sqrt{(-1)^{2}+2^{2}}=\sqrt5,\;
# u_{2}=v_{2}/\!\sqrt5=\frac1{\sqrt5}(-1,2)^{\top}.
# $
#
#
# $
# u_{1}^{\!\top}u_{2}=0\;(\text{as expected for a symmetric }A).
# $
#
#
# $
# \textbf{Step 4.  Assemble the spectral decomposition}
# $
#
#
# $
# A
# =\lambda_{1}u_{1}u_{1}^{\!\top}+\lambda_{2}u_{2}u_{2}^{\!\top}
# =8\!\bigl(u_{1}u_{1}^{\!\top}\bigr)+3\!\bigl(u_{2}u_{2}^{\!\top}\bigr).
# $
#
#
# $
# u_{1}u_{1}^{\!\top}
# =\frac15\begin{pmatrix}4&2\\2&1\end{pmatrix},\quad
# u_{2}u_{2}^{\!\top}
# =\frac15\begin{pmatrix}1&-2\\-2&4\end{pmatrix}.
# $
#
# $
# \boxed{%
# A=\frac85\!\begin{pmatrix}4&2\\2&1\end{pmatrix}
#       +\frac35\!\begin{pmatrix}1&-2\\-2&4\end{pmatrix}
# }.
# $
#
#
# $
# \text{Expanding confirms }A=\begin{pmatrix}7&2\\2&4\end{pmatrix}.
# $

# %% [markdown]
# $\|v_{1}\|=\sqrt{2^{2}+1^{2}}=\sqrt5,\;
# u_{1}=v_{1}/\!\sqrt5=\frac1{\sqrt5}(2,1)^{\top}.
# $
# $
# \|v_{2}\|=\sqrt{(-1)^{2}+2^{2}}=\sqrt5,\;
# u_{2}=v_{2}/\!\sqrt5=\frac1{\sqrt5}(-1,2)^{\top}.
# $
#
# $
# u_{1}^{\!\top}u_{2}=0\;(\text{as expected for a symmetric }A).
# $
#
# $
# \textbf{Step 4.  Assemble the spectral decomposition}
# $
#
# $
# A
# =\lambda_{1}u_{1}u_{1}^{\!\top}+\lambda_{2}u_{2}u_{2}^{\!\top}
# =8\!\bigl(u_{1}u_{1}^{\!\top}\bigr)+3\!\bigl(u_{2}u_{2}^{\!\top}\bigr).
# $
#
# $
# u_{1}u_{1}^{\!\top}
# =\frac15\begin{pmatrix}4&2\\2&1\end{pmatrix},\quad
# u_{2}u_{2}^{\!\top}
# =\frac15\begin{pmatrix}1&-2\\-2&4\end{pmatrix}.
# $
#
# $
# \boxed{%
# A=\frac85\!\begin{pmatrix}4&2\\2&1\end{pmatrix}
#       +\frac35\!\begin{pmatrix}1&-2\\-2&4\end{pmatrix}
# }.
# $
#
# $
# \text{Expanding confirms }A=\begin{pmatrix}7&2\\2&4\end{pmatrix}.
# $

# %% [markdown]
# $
# \underline{\text{4.  Spectral (eigendecomposition)}}
# $
#
# $
# \;
# \boxed{A=\lambda_{1}\,u_{1}u_{1}^{\!\top}+\lambda_{2}\,u_{2}u_{2}^{\!\top}}.
# $
#
# $
# \text{Compute the rank-1 projectors:}
# $
# $
# \;
# u_{1}u_{1}^{\!\top}=\frac15\!\begin{pmatrix}4&2\\2&1\end{pmatrix},\quad
# u_{2}u_{2}^{\!\top}=\frac15\!\begin{pmatrix}1&-2\\-2&4\end{pmatrix}.
# $
#
# $
# \Rightarrow
# $
# $
# A
# =8\!\left(\frac15\begin{pmatrix}4&2\\2&1\end{pmatrix}\right)
# +3\!\left(\frac15\begin{pmatrix}1&-2\\-2&4\end{pmatrix}\right)
# =\begin{pmatrix}7&2\\2&4\end{pmatrix}\;(\checkmark)
# $
